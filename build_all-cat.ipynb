# %% [markdown]
# # Build catalog from the input files for the bias correction

# %% [markdown]
# Date: 7 June 2024

# %% [markdown]
# Author = {"name": "Richard Matear","affiliation": "CSIRO", "email": "thomas.moore@csiro.au", "orcid": "0000-0003-3930-1946"}

# %% [markdown]
# #### Reference documents: https://ecgtools.readthedocs.io/en/latest

# %%
import glob
import pathlib
import traceback
from datetime import datetime

import xarray as xr

from ecgtools import Builder
from ecgtools.builder import INVALID_ASSET, TRACEBACK

from matplotlib import pyplot as plt

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# 2024-06-09 20:33:21,326 - distributed.preloading - INFO - Creating preload: /g/data/hh5/public/apps/dask-optimiser/schedplugin.py
# 2024-06-09 20:33:21,328 - distributed.utils - INFO - Reload module schedplugin from .py file
# 2024-06-09 20:33:21,351 - distributed.preloading - INFO - Import preload module: /g/data/hh5/public/apps/dask-optimiser/schedplugin.py
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41173 instead
#   warnings.warn(
# Modifying workers
# <Client: 'tcp://127.0.0.1:38125' processes=2 threads=2, memory=9.00 GiB>

# %% [markdown]
# ### get path from config

# %%
import configparser

# Create a ConfigParser object
config = configparser.ConfigParser()

# Read the config file
config.read('/g/data/xv83/rxm599/acs/data-catalogue/config.ini')

# Get the value of a variable
catalogue_path = config.get('paths', 'catalogue_path')

# %% [markdown]
# ### build the catalogue from the listing of files on `xv83`

# %%
# build list of future simulations but omit the historical simulations

# create a base name for location of files
root_version= '/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/'
mBoM = sorted(glob.iglob(root_version+'AGCD-05i/BOM/*/[!hi]*/*/*/*/*'))
mCSIRO = sorted(glob.iglob(root_version+'AGCD-05i/CSIRO/*/[!hi]*/*/*/*/*'))
mRuns=mBoM+mCSIRO

# extract location of root location for a simulation
def r_model(mRun):
    b=mRun.split('/')
    c=b[8:]
    d='/'.join(c)
    return d

# number of individual simulations in the bias_input directory
print(len(mRuns))
# Out:
# 17

# %%
for file in mRuns: 
    root_model=(r_model(file)) 
    root_source_path =  root_version+root_model+'/'
    files = sorted(glob.glob(root_source_path+'*/*'))
    print(root_source_path)
    print(len(files))
# Out:
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/ACCESS-CM2/ssp370/r4i1p1f1/BARPA-R/v1-r1/day/
# 602
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/ACCESS-ESM1-5/ssp370/r6i1p1f1/BARPA-R/v1-r1/day/
# 602
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/CESM2/ssp370/r11i1p1f1/BARPA-R/v1-r1/day/
# 602
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/CMCC-ESM2/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/EC-Earth3/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/MPI-ESM1-2-HR/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/NorESM2-MM/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-CM2/ssp126/r4i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-CM2/ssp370/r4i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-ESM1-5/ssp126/r6i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-ESM1-5/ssp370/r6i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CESM2/ssp126/r11i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CESM2/ssp370/r11i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CMCC-ESM2/ssp126/r1i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CMCC-ESM2/ssp370/r1i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CNRM-ESM2-1/ssp370/r1i1p1f2/CCAM-v2203-SN/v1-r1/day/
# 595
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/EC-Earth3/ssp370/r1i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595

# %%
def parse_CCAM(file):
    """CCAM data stored in"""
    file = pathlib.Path(file)
    info = {}

    try:
        stem = file.stem
        split = stem.split('_')
        variable = split[0]
        domain = split[1]
        host_GCM = split[2]
        run_type = split[3]
        host_ensemble = split[4]
        downscale_model = split[5]
        downscale_version = split[6]
        period = split[7]
        if period == '1hr':
            time_period = 'hourly'
        elif period == '6hr':
            time_period = 'six_hourly'
        elif period == 'day':
            time_period = 'daily'
        elif period == 'mon':
            time_period = 'monthly'
        else:
            time_period = 'fixed'    

        
        info = {
            'variable': variable,
            'domain': domain,
            'host_GCM':host_GCM,
            'run_type':run_type,
            'host_ensemble':host_ensemble,
            'downscale_model':downscale_model,
            'downscale_version':downscale_version,
            'period': period,
            'time_period': time_period,
            'path': str(file),
        }
        return info
    
    except Exception:
        return {INVALID_ASSET: file, TRACEBACK: traceback.format_exc()}

# %% [markdown]
# # Create catalogue for each future simulation in the bias_input directory

# %%
# %%time
for file in mRuns: 
    root_model=(r_model(file)) 
    root_source_path =  root_version+root_model+'/'
    files = sorted(glob.glob(root_source_path+'*/*'))
    print(root_source_path)
    print(len(files))
# build catalogue    
    b = Builder([root_source_path],depth=2)
    b.build(parsing_func = parse_CCAM)
    model=root_model.replace("/", "_")
    print(model)
#
    b.save(
    # File path - could save as .csv (uncompressed csv) or .csv.gz (compressed csv)
        name = model,
        directory = catalogue_path,
    # Column name including filepath
        path_column_name='path',
    # Column name including variables
        variable_column_name='variable',
    # Data file format - could be netcdf or zarr (in this case, netcdf)
        data_format="netcdf",
    # Which attributes to groupby when reading in variables using intake-esm
        groupby_attrs=["domain", "host_GCM", "run_type","host_ensemble","downscale_model","downscale_version","period"],
    # Aggregations which are fed into xarray when reading in data using intake
        aggregations=[
        {
            "type": "join_existing",
            "attribute_name": "date",
            "options": {"dim": "time", "coords": "minimal", "compat": "override"},
        }
        ],
    )
# Out:
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/ACCESS-CM2/ssp370/r4i1p1f1/BARPA-R/v1-r1/day/
# 602
# AGCD-05i_BOM_ACCESS-CM2_ssp370_r4i1p1f1_BARPA-R_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_BOM_ACCESS-CM2_ssp370_r4i1p1f1_BARPA-R_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/ACCESS-ESM1-5/ssp370/r6i1p1f1/BARPA-R/v1-r1/day/
# 602
# AGCD-05i_BOM_ACCESS-ESM1-5_ssp370_r6i1p1f1_BARPA-R_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_BOM_ACCESS-ESM1-5_ssp370_r6i1p1f1_BARPA-R_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/CESM2/ssp370/r11i1p1f1/BARPA-R/v1-r1/day/
# 602
# AGCD-05i_BOM_CESM2_ssp370_r11i1p1f1_BARPA-R_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_BOM_CESM2_ssp370_r11i1p1f1_BARPA-R_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/CMCC-ESM2/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# AGCD-05i_BOM_CMCC-ESM2_ssp370_r1i1p1f1_BARPA-R_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_BOM_CMCC-ESM2_ssp370_r1i1p1f1_BARPA-R_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/EC-Earth3/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# AGCD-05i_BOM_EC-Earth3_ssp370_r1i1p1f1_BARPA-R_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_BOM_EC-Earth3_ssp370_r1i1p1f1_BARPA-R_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/MPI-ESM1-2-HR/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# AGCD-05i_BOM_MPI-ESM1-2-HR_ssp370_r1i1p1f1_BARPA-R_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_BOM_MPI-ESM1-2-HR_ssp370_r1i1p1f1_BARPA-R_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/BOM/NorESM2-MM/ssp370/r1i1p1f1/BARPA-R/v1-r1/day/
# 602
# AGCD-05i_BOM_NorESM2-MM_ssp370_r1i1p1f1_BARPA-R_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_BOM_NorESM2-MM_ssp370_r1i1p1f1_BARPA-R_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-CM2/ssp126/r4i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# AGCD-05i_CSIRO_ACCESS-CM2_ssp126_r4i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_ACCESS-CM2_ssp126_r4i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-CM2/ssp370/r4i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# AGCD-05i_CSIRO_ACCESS-CM2_ssp370_r4i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_ACCESS-CM2_ssp370_r4i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-ESM1-5/ssp126/r6i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# AGCD-05i_CSIRO_ACCESS-ESM1-5_ssp126_r6i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_ACCESS-ESM1-5_ssp126_r6i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/ACCESS-ESM1-5/ssp370/r6i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# AGCD-05i_CSIRO_ACCESS-ESM1-5_ssp370_r6i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_ACCESS-ESM1-5_ssp370_r6i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CESM2/ssp126/r11i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# AGCD-05i_CSIRO_CESM2_ssp126_r11i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_CESM2_ssp126_r11i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CESM2/ssp370/r11i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# AGCD-05i_CSIRO_CESM2_ssp370_r11i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_CESM2_ssp370_r11i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CMCC-ESM2/ssp126/r1i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 425
# AGCD-05i_CSIRO_CMCC-ESM2_ssp126_r1i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_CMCC-ESM2_ssp126_r1i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CMCC-ESM2/ssp370/r1i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# AGCD-05i_CSIRO_CMCC-ESM2_ssp370_r1i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_CMCC-ESM2_ssp370_r1i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/CNRM-ESM2-1/ssp370/r1i1p1f2/CCAM-v2203-SN/v1-r1/day/
# 595
# AGCD-05i_CSIRO_CNRM-ESM2-1_ssp370_r1i1p1f2_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_CNRM-ESM2-1_ssp370_r1i1p1f2_CCAM-v2203-SN_v1-r1_day.json
# /g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-input/AGCD-05i/CSIRO/EC-Earth3/ssp370/r1i1p1f1/CCAM-v2203-SN/v1-r1/day/
# 595
# AGCD-05i_CSIRO_EC-Earth3_ssp370_r1i1p1f1_CCAM-v2203-SN_v1-r1_day
# Successfully wrote ESM catalog json file to: file:///g/data/xv83/rxm599/acs/data-catalogue/catalogues/AGCD-05i_CSIRO_EC-Earth3_ssp370_r1i1p1f1_CCAM-v2203-SN_v1-r1_day.json
# CPU times: user 1.17 s, sys: 673 ms, total: 1.85 s
# Wall time: 6.83 s

# %% [markdown]
# # THE END

# %%
client.shutdown()
